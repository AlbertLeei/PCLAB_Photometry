# %% [markdown]
# # Group Analysis Code

# %%
import tdt
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from group_tdt_class import *

# %%
experiment_path = r"C:\Users\alber\OneDrive\Desktop\PC_Lab\Photometry\Pilot_2\Combined\Hab_Dishab\mpfc"
csv_base_path = r"C:\Users\alber\OneDrive\Desktop\PC_Lab\Photometry\Pilot_2\Combined\Hab_Dishab\mpfc_csvs"

# %%
group_data = GroupTDTData(experiment_path, csv_base_path)
# group_data.load_blocks()
group_data.list_blocks()
group_data.batch_process()
group_data.hab_dishab_processing()
# group_data.plot_behavior(behavior_name='Pinch', plot_type='dFF')
# Out:
# Found Synapse note file: C:\Users\alber\OneDrive\Desktop\PC_Lab\Photometry\Pilot_2\Combined\Hab_Dishab\mpfc\p1-240516-064158\Notes.txt
# read from t=0s to t=1547.64s
# Found Synapse note file: C:\Users\alber\OneDrive\Desktop\PC_Lab\Photometry\Pilot_2\Combined\Hab_Dishab\mpfc\p2-240516-071921\Notes.txt
# read from t=0s to t=1556.22s
# Found Synapse note file: C:\Users\alber\OneDrive\Desktop\PC_Lab\Photometry\Pilot_2\Combined\Hab_Dishab\mpfc\p3-240516-075659\Notes.txt
# read from t=0s to t=1538.85s
# Found Synapse note file: C:\Users\alber\OneDrive\Desktop\PC_Lab\Photometry\Pilot_2\Combined\Hab_Dishab\mpfc\p4-240516-083255\Notes.txt
# read from t=0s to t=1773.98s
# Found Synapse note file: C:\Users\alber\OneDrive\Desktop\PC_Lab\Photometry\Pilot_2\Combined\Hab_Dishab\mpfc\p5-240821-092649\Notes.txt
# read from t=0s to t=1326.46s
# Found Synapse note file: C:\Users\alber\OneDrive\Desktop\PC_Lab\Photometry\Pilot_2\Combined\Hab_Dishab\mpfc\p6-240821-103616\Notes.txt
# read from t=0s to t=1322.66s
# Found Synapse note file: C:\Users\alber\OneDrive\Desktop\PC_Lab\Photometry\Pilot_2\Combined\Hab_Dishab\mpfc\p7-240821-111323\Notes.txt
# read from t=0s to t=1325.21s
# Found Synapse note file: C:\Users\alber\OneDrive\Desktop\PC_Lab\Photometry\Pilot_2\Combined\Hab_Dishab\mpfc\p8-240821-121933\Notes.txt
# read from t=0s to t=1315.26s
# Processing p1-240516-064158...
# Processing p2-240516-071921...
# Processing p3-240516-075659...
# Processing p4-240516-083255...
# Processing p5-240821-092649...
# Processing p6-240821-103616...
# Processing p7-240821-111323...
# Processing p8-240821-121933...
# Processing p1-240516-064158...
# Finished processing p1-240516-064158
# Processing p2-240516-071921...
# Finished processing p2-240516-071921
# Processing p3-240516-075659...
# Finished processing p3-240516-075659
# Processing p4-240516-083255...
# Finished processing p4-240516-083255
# Processing p5-240821-092649...
# Finished processing p5-240821-092649
# Processing p6-240821-103616...
# Finished processing p6-240821-103616
# Processing p7-240821-111323...
# Finished processing p7-240821-111323
# Processing p8-240821-121933...
# Finished processing p8-240821-121933

# %%
# group_data.compute_group_psth(behavior_name='Investigation', pre_time=3, post_time=3, signal_type='zscore')
# group_data.plot_group_psth(behavior_name='Pinch', pre_time=3, post_time=3, signal_type='zscore')

# %%
group_data.hab_dishab_plot_individual_behavior(behavior_name='all',figsize=(20,8))

# %% [markdown]
# If you want to grab a single object and visualize it:

# %%
# tdt_data_obj= group_data.get_block(block_name='n6-240820-090055')
# # Remove initial LED artifact
# tdt_data_obj.remove_initial_LED_artifact(t=10)

# tdt_data_obj.smooth_signal()
# tdt_data_obj.verify_signal()
# # Plot raw trace
# tdt_data_obj.plot('raw')
