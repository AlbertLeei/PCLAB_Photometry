# %% [markdown]
# # Social Preference Redo

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

from Social_Pref_Commands import *

# %% [markdown]
# Combined all data (fib pho and Sequioa's)

# %%
# Define paths
all_csvs_folder = r"C:\Users\alber\OneDrive\Desktop\PC_Lab\Photometry\Pilot_2\Social Preference Redo\Data\All_csvs"
cup_assignment_excel_path = r"C:\Users\alber\OneDrive\Desktop\PC_Lab\Photometry\Pilot_2\Social Preference Redo\Data\Social_Pref_sheet.xlsx"

# Run the processing function
subject_behavior_data = process_all_behavior_files(all_csvs_folder, cup_assignment_excel_path)


# Display or save the result as needed
subject_behavior_data['n1']['nothing']
# Out:
# {'sniff': [{'Start Time': 197.0, 'End Time': 199.933, 'Duration': 2.933},
#   {'Start Time': 221.933, 'End Time': 222.667, 'Duration': 0.734},
#   {'Start Time': 261.8, 'End Time': 263.067, 'Duration': 1.267},
#   {'Start Time': 294.0, 'End Time': 300.067, 'Duration': 6.067},
#   {'Start Time': 318.467, 'End Time': 320.2, 'Duration': 1.733},
#   {'Start Time': 358.267, 'End Time': 358.8, 'Duration': 0.533},
#   {'Start Time': 423.267, 'End Time': 425.067, 'Duration': 1.8},
#   {'Start Time': 426.867, 'End Time': 432.8, 'Duration': 5.933},
#   {'Start Time': 473.267, 'End Time': 474.333, 'Duration': 1.066},
#   {'Start Time': 503.533, 'End Time': 508.333, 'Duration': 4.8},
#   {'Start Time': 566.533, 'End Time': 567.4, 'Duration': 0.867},
#   {'Start Time': 609.333, 'End Time': 614.0, 'Duration': 4.667},
#   {'Start Time': 656.733, 'End Time': 657.6, 'Duration': 0.867},
#   {'Start Time': 697.667, 'End Time': 701.6, 'Duration': 3.933},
# ...

# %%
# Calculate the average "sniff" duration for each bout across subjects
average_sniff_duration_df = calculate_average_sniff_duration_per_bout(subject_behavior_data)

# %%
# average_sniff_duration_df

# %%
# Define custom x-tick labels and colors
custom_xlabels = ['Empty', 'Short Term', 'Long Term', 'Novel']
colors = ['#000000', '#0045A6', '#A839A4', '#E06928']

# Plot the data
plot_y_across_bouts_colors(average_sniff_duration_df)
# Out:
# c:\Users\alber\OneDrive\Documents\GitHub\PCLAB_Photometry\Social_Pref_Redo\Social_Pref_Commands.py:262: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(df.columns, fontsize=14)

# %% [markdown]
# Dominance Rankings
