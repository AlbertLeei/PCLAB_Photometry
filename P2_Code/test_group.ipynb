# %% [markdown]
# # Group Analysis Code

# %%
import tdt
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from group_tdt_class import *

# %%
experiment_path = r"C:\Users\alber\OneDrive\Documents\GitHub\PCLAB_Photometry\P2_Code\tdt_pinch_test"
csv_base_path = r"C:\Users\alber\OneDrive\Documents\GitHub\PCLAB_Photometry\P2_Code\08_20_24_C2_Pinch_Test"

# %%
group_data = GroupTDTData(experiment_path, csv_base_path)
# group_data.load_blocks()
group_data.list_blocks()
group_data.batch_process()
# group_data.plot_behavior(behavior_name='Pinch', plot_type='dFF')
# Out:
# Found Synapse note file: C:\Users\alber\OneDrive\Documents\GitHub\PCLAB_Photometry\P2_Code\tdt_pinch_test\n6-240820-090055\Notes.txt
# read from t=0s to t=225.14s
# Found Synapse note file: C:\Users\alber\OneDrive\Documents\GitHub\PCLAB_Photometry\P2_Code\tdt_pinch_test\n7-240820-090819\Notes.txt
# read from t=0s to t=133.83s
# Processing n6-240820-090055...
# Processing n7-240820-090819...

# %%
group_data.compute_group_psth(behavior_name='Pinch', pre_time=3, post_time=3, signal_type='zscore')
group_data.plot_group_psth(behavior_name='Pinch', pre_time=3, post_time=3, signal_type='zscore')

# %%
group_data.plot_individual_psths()

# %% [markdown]
# If you want to grab a single object and visualize it:

# %%
# tdt_data_obj= group_data.get_block(block_name='n6-240820-090055')
# # Remove initial LED artifact
# tdt_data_obj.remove_initial_LED_artifact(t=10)

# tdt_data_obj.smooth_signal()
# tdt_data_obj.verify_signal()
# # Plot raw trace
# tdt_data_obj.plot('raw')
